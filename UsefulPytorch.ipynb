# %% [markdown]
# ***Mounting GDrive & Installing Pytorch***

# %%
import os
from google.colab import drive

# 1. Mounting GDrive
drive.mount('/content/drive/')

# 2. Installing Pytorch
# !pip3 install torch torchvision

# 3. Other dependencies 
# !pip install helper
# !pip install bokeh
# !pip install opencv-contrib-python

# 4. changing our working directory 
MyPath = '/content/drive/My Drive/Colab Notebooks/Python Notebooks/Tutorials/PyTorch Scholarship Challenge/Deep Learning (PyTorch)/'
os.chdir(MyPath+'intro-to-pytorch')
